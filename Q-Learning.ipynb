# %%
import random 
import numpy as np

def stateEncoder(s):
    if s==1:
        return (1,8)
    if s==2:
        return (2,8)
    if s==3:
        return (3,8)
    if s==4:
        return (4,8)
    if s==5:
        return (5,8)
    if s==6:
        return (6,8)
    if s==7:
        return (7,8)
    if s==8:
        return (8,8)
    if s==9:
        return (9,8)
    if s==10:
        return (10,8)
    if s==11:
        return (1,"Taxi")
    if s==12:
        return (2,"Taxi")
    if s==13:
        return (3,"Taxi")
    if s==14:
        return (4,"Taxi")
    if s==15:
        return (5,"Taxi")
    if s==16:
        return (6,"Taxi")
    if s==17:
        return (7,"Taxi")
    if s==18:
        return (8,"Taxi")
    if s==19:
        return (9,"Taxi")
    if s==20:
        return (10,"Taxi")
    
def actionEncoder(a):
    if a==1:
        return "Yukarı"
    if a==2:
        return "Aşağı"
    if a==3:
        return "Sağ"
    if a==4:
        return "Sol"
    if a==5:
        return "Al"
    if a==6:
        return "Bırak"
    
def Environment(s,a):
    
    
    s = stateEncoder(s)
    
    
    if s==(1,8):
        if a==1: #Yukarı
            return [1, 1, -1, False]
        if a==2: #Aşağı
            return [1, 1, -1, False]
        if a==3:#Sağ
            return [1, 1, -1, False]
        if a==4: #Sol
            return [1, 2, -1, False]
        if a==5: #Al
            return [1, 1, -10, False]
        if a==6: #Bırak
            return [1, 1, -10, False]
        
    if s==(2,8):
        if a==1: #Yukarı
            return [1, 5, -1, False]
        if a==2: #Aşağı
            return [1, 2, -1, False]
        if a==3:#Sağ
            return [1, 1, -1, False]
        if a==4: #Sol
            return [1, 3, -1, False]
        if a==5: #Al
            return [1, 2, -10, False]
        if a==6: #Bırak
            return [1, 2, -10, False]
    
    if s==(3,8):
        if a==1: #Yukarı
            return [1, 4, -1, False]
        if a==2: #Aşağı
            return [1, 3, -1, False]
        if a==3:#Sağ
            return [1, 2, -1, False]
        if a==4: #Sol
            return [1, 3, -1, False]
        if a==5: #Al
            return [1, 3, -10, False]
        if a==6: #Bırak
            return [1, 2, -10, False]
    
    if s==(4,8):
        if a==1: #Yukarı
            return [1, 6, -1, False]
        if a==2: #Aşağı
            return [1, 3, -1, False]
        if a==3:#Sağ
            return [1, 5, -1, False]
        if a==4: #Sol
            return [1, 4, -1, False]
        if a==5: #Al
            return [1, 4, -10, False]
        if a==6: #Bırak
            return [1, 4, -10, False]
        
    if s==(5,8):
        if a==1: #Yukarı
            return [1, 7, -1, False]
        if a==2: #Aşağı
            return [1, 2, -1, False]
        if a==3:#Sağ
            return [1, 5, -1, False]
        if a==4: #Sol
            return [1, 4, -1, False]
        if a==5: #Al
            return [1, 5, -10, False]
        if a==6: #Bırak
            return [1, 5, -10, False]
        
    if s==(6,8):
        if a==1: #Yukarı
            return [1, 9, -1, False]
        if a==2: #Aşağı
            return [1, 4, -1, False]
        if a==3:#Sağ
            return [1, 7, -1, False]
        if a==4: #Sol
            return [1, 6, -1, False]
        if a==5: #Al
            return [1, 6, -10, False]
        if a==6: #Bırak
            return [1, 6, -10, False]
        
    if s==(7,8):
        if a==1: #Yukarı
            return [1, 10, -1, False]
        if a==2: #Aşağı
            return [1, 5, -1, False]
        if a==3:#Sağ
            return [1, 8, -1, False]
        if a==4: #Sol
            return [1, 6, -1, False]
        if a==5: #Al
            return [1, 7, -10, False]
        if a==6: #Bırak
            return [1, 7, -10, False]
        
    if s==(8,8):
        if a==1: #Yukarı
            return [1, 8, -1, False]
        if a==2: #Aşağı
            return [1, 8, -1, False]
        if a==3:#Sağ
            return [1, 8, -1, False]
        if a==4: #Sol
            return [1, 7, -1, False]
        if a==5: #Al
            return [1, 18, 100, False]
        if a==6: #Bırak
            return [1, 8, -10, False]
        
    if s==(9,8):
        if a==1: #Yukarı
            return [1, 8, -1, False]
        if a==2: #Aşağı
            return [1, 8, -1, False]
        if a==3:#Sağ
            return [1, 8, -1, False]
        if a==4: #Sol
            return [1, 7, -1, False]
        if a==5: #Al
            return [1, 1, -10, False]
        if a==6: #Bırak
            return [1, 8, -10, False]
        
    if s==(10,8):
        if a==1: #Yukarı
            return [1, 10, -1, False]
        if a==2: #Aşağı
            return [1, 7, -1, False]
        if a==3:#Sağ
            return [1, 10, -1, False]
        if a==4: #Sol
            return [1, 9, -1, False]
        if a==5: #Al
            return [1, 10, -10, False]
        if a==6: #Bırak
            return [1, 10, -10, False]
        
    if s==(1,"Taxi"):
        if a==1: #Yukarı
            return [1, 11, -1, False]
        if a==2: #Aşağı
            return [1, 11, -1, False]
        if a==3:#Sağ
            return [1, 11, -1, False]
        if a==4: #Sol
            return [1, 12, -1, False]
        if a==5: #Al
            return [1, 11, -10, False]
        if a==6: #Bırak
            return [1, 11, 100, True]
        
    if s==(2,"Taxi"):
        if a==1: #Yukarı
            return [1, 15, -1, False]
        if a==2: #Aşağı
            return [1, 12, -1, False]
        if a==3:#Sağ
            return [1, 11, -1, False]
        if a==4: #Sol
            return [1, 13, -1, False]
        if a==5: #Al
            return [1, 12, -10, False]
        if a==6: #Bırak
            return [1, 12, -10, True]
        
    if s==(3,"Taxi"):
        if a==1: #Yukarı
            return [1, 14, -1, False]
        if a==2: #Aşağı
            return [1, 13, -1, False]
        if a==3:#Sağ
            return [1, 12, -1, False]
        if a==4: #Sol
            return [1, 13, -1, False]
        if a==5: #Al
            return [1, 13, -10, False]
        if a==6: #Bırak
            return [1, 13, -10, True]
        
    if s==(4,"Taxi"):
        if a==1: #Yukarı
            return [1, 16, -1, False]
        if a==2: #Aşağı
            return [1, 13, -1, False]
        if a==3:#Sağ
            return [1, 15, -1, False]
        if a==4: #Sol
            return [1, 14, -1, False]
        if a==5: #Al
            return [1, 14, -10, False]
        if a==6: #Bırak
            return [1, 14, -10, True]
    
    if s==(5,"Taxi"):
        if a==1: #Yukarı
            return [1, 17, -1, False]
        if a==2: #Aşağı
            return [1, 12, -1, False]
        if a==3:#Sağ
            return [1, 14, -1, False]
        if a==4: #Sol
            return [1, 14, -1, False]
        if a==5: #Al
            return [1, 14, -10, False]
        if a==6: #Bırak
            return [1, 14, -10, True]
        
    if s==(6,"Taxi"):
        if a==1: #Yukarı
            return [1, 19, -1, False]
        if a==2: #Aşağı
            return [1, 14, -1, False]
        if a==3:#Sağ
            return [1, 17, -1, False]
        if a==4: #Sol
            return [1, 16, -1, False]
        if a==5: #Al
            return [1, 16, -10, False]
        if a==6: #Bırak
            return [1, 16, -10, True]
        
    if s==(7,"Taxi"):
        if a==1: #Yukarı
            return [1, 20, -1, False]
        if a==2: #Aşağı
            return [1, 15, -1, False]
        if a==3:#Sağ
            return [1, 18, -1, False]
        if a==4: #Sol
            return [1, 16, -1, False]
        if a==5: #Al
            return [1, 17, -10, False]
        if a==6: #Bırak
            return [1, 17, -10, True]
        
    if s==(8,"Taxi"):
        if a==1: #Yukarı
            return [1, 18, -1, False]
        if a==2: #Aşağı
            return [1, 18, -1, False]
        if a==3:#Sağ
            return [1, 18, -1, False]
        if a==4: #Sol
            return [1, 17, -1, False]
        if a==5: #Al
            return [1, 18, -10, False]
        if a==6: #Bırak
            return [1, 18, -10, True]
        
    if s==(9,"Taxi"):
        if a==1: #Yukarı
            return [1, 19, -1, False]
        if a==2: #Aşağı
            return [1, 16, -1, False]
        if a==3:#Sağ
            return [1, 20, -1, False]
        if a==4: #Sol
            return [1, 19, -1, False]
        if a==5: #Al
            return [1, 19, -10, False]
        if a==6: #Bırak
            return [1, 19, -10, True]
        
    if s==(10,"Taxi"):
        if a==1: #Yukarı
            return [1, 20, -1, False]
        if a==2: #Aşağı
            return [1, 17, -1, False]
        if a==3:#Sağ
            return [1, 20, -1, False]
        if a==4: #Sol
            return [1, 19, -1, False]
        if a==5: #Al
            return [1, 20, -10, False]
        if a==6: #Bırak
            return [1, 20, -10, True]
        

#MAIN**********************************************************


q_table = np.zeros([20,6])
episode = 1000
epsilon = 0.1
alpha = 0.1
gamma = 0.9 

reward_list = []
time_list = []
gameover_list = []

gameover_rate = 0
win = 0

for i in range(episode):
    
    #initalize environment
    state = random.randrange(1,11)
    t=0
    counter = 0
    total_reward = 0
    
    while(True):
        
        #print("Time: ",t)
        #print("Current state: ", stateEncoder(state))
        
        if random.uniform(0,1) < epsilon:
            action = random.randrange(1,7)
        else:
            action = np.argmax(q_table[state-1]) + 1
        
        #print("Action verildi : ", actionEncoder(action))
        
        
        observations = Environment(state,action)
        next_state = observations[1]
        reward = observations[2]
        done = observations[3]
        
        #print("Next state ve ödül: ", next_state, reward)
        #print("*************************************")
        
        
        old_Q = q_table[state-1,action-1]
        next_max = np.max(q_table[next_state-1])
        new_Q = (1-alpha)*old_Q + alpha*(reward + gamma*next_max)
        q_table[state-1,action-1] = new_Q
        
        state = next_state

        total_reward = total_reward + reward
        t = t + 1
        

        #print(total_reward)

        if done == True: #done True is taxi indirmiştir.
            reward_list.append(total_reward)
            time_list.append(t)
            
            if(state==11): #doğru yerde indirdi
                win = win + 1
            else: #yanlış yerde indirdi
                gameover_rate = gameover_rate + 1
            
            #print("Episode is done. ****************************************************************")
            
            break



print(gameover_rate)
print(win)
# Out:
# 92
# 908

# %%
print(reward_list,"\n\n\n")
# Out:
# [57, 44, -8, 65, 1, 37, 75, 65, 35, 125, 164, 83, 171, 166, 183, 185, 196, 83, 147, 194, 193, 189, 180, 194, 195, 187, 189, 194, 194, 193, 192, 194, 191, 192, 194, 73, 182, 194, 194, 194, 191, 190, 189, 194, 180, 194, 186, 84, 183, 180, 193, 196, 193, 192, 193, 194, 181, 193, 193, 192, 194, 190, 194, 182, 192, 196, 183, 88, 184, 196, 195, 193, 194, 194, 88, 196, 85, 186, 194, 193, 195, 196, 193, 190, 179, 184, 193, 194, 194, 192, 193, 192, 194, 193, 194, 192, 193, 84, 184, 85, 196, 171, 77, 193, 193, 191, 193, 194, 193, 196, 181, 194, 193, 194, 194, 193, 194, 192, 191, 192, 194, 193, 195, 193, 194, 86, 196, 192, 195, 194, 192, 194, 182, 192, 194, 182, 192, 192, 182, 192, 196, 194, 196, 192, 195, 194, 194, 194, 194, 181, 192, 195, 183, 191, 194, 194, 194, 190, 192, 183, 194, 195, 193, 195, 82, 192, 195, 193, 192, 83, 192, 194, 194, 196, 194, 193, 182, 192, 192, 192, 191, 182, 86, 192, 190, 192, 194, 172, 196, 86, 181, 192, 191, 195, 194, 191, 194, 192, 193, 195, 184, 193, 195, 89, 194
# ...
